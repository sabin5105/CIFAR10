# %%
from baseline import *
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# initialize random forest
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(random_state=0)

# %%
rf_clf.fit(trainset.data.reshape(50000, 3072), trainset.targets)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred = rf_clf.predict(testset.data.reshape(10000, 3072))

# %%
# accuracy
print("Accuracy: ", accuracy_score(testset.targets, pred))
print("F1 Score: ", f1_score(testset.targets, pred, average='macro'))
print("Recall: ", recall_score(testset.targets, pred, average='macro'))
print("Precision: ", precision_score(testset.targets, pred, average='macro'))
print("-"*70)

# visualize confusion matrix
cm = confusion_matrix(testset.targets, pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap='Greys')
plt.title("Confusion matrix")
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# classification report
print("Classification Report: ", classification_report(testset.targets, pred))
# Out:
# Accuracy:  0.4651
# F1 Score:  0.4611192302688266
# Recall:  0.46509999999999996
# Precision:  0.4598054148276759
# ----------------------------------------------------------------------
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.54      0.56      0.55      1000
#            1       0.51      0.54      0.53      1000
#            2       0.35      0.32      0.34      1000
#            3       0.33      0.26      0.29      1000
#            4       0.40      0.39      0.39      1000
#            5       0.42      0.39      0.40      1000
#            6       0.47      0.56      0.51      1000
#            7       0.50      0.45      0.47      1000
#            8       0.59      0.61      0.60      1000
#            9       0.48      0.56      0.52      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.46      0.47      0.46     10000
# weighted avg       0.46      0.47      0.46     10000

# %% [markdown]
# ## Conclusion
# * ### Random Forest (ensenble) - OVERFITTING
#
# It looks like the training is quite messed up
#
# However, we could figure out that the result is better than Decision Tree
#
# The reason why it's based on Decision Tree
#
# * The Random Forest also has a problem about **overfitting** with training set
#
# * Hard to understand what kinds of tree has made
#
# Definitely apply another models
#
# <hr>
#
# ## Score
# * ### test score
#   * Accuracy:  0.4651
#   * F1 Score:  0.4611192302688266
#   * Recall:  0.46509999999999996
#   * Precision:  0.4598054148276759
#   *
# <hr>
#
# This is just for academic purpose
# So, I ain't gonna evolve this by hyperparameter-tunings as well
#
# Using default parameters
#
# <hr>
#
# ### But gotta check the sequence and flow is correct
